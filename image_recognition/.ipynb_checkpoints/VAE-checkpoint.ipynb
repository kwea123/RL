# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Using TensorFlow backend.

# %%
X_train=X_train/255
X_test=X_test/255

# %%
plt.imshow(X_train[0], cmap='gray')
y_train[0]
# Out:
# 5

# %%
class VAE():
    def __init__(self, n_latent=2):
        self.n_latent = n_latent
        self._build_encoder()
        self._build_decoder()
        
        epsilon = 1e-10
        self.reconstruction_loss = -tf.reduce_sum(self.x_flat*tf.log(self.x_hat+epsilon)+(1-self.x_flat)*tf.log(1-self.x_hat+epsilon),axis=1)
        self.latent_loss = -0.5*tf.reduce_sum(1+self.z_logvar-tf.square(self.z_mu)- tf.exp(self.z_logvar), axis=1)
        self.loss = tf.reduce_mean(self.reconstruction_loss+self.latent_loss)
        self.train_op = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(self.loss)
        
        self.sess = tf.Session()
        self.sess.run(tf.global_variables_initializer())
        self.saver = tf.train.Saver()
        
    def _build_encoder(self):
        self.x = tf.placeholder(dtype=tf.float32,shape=[None, 28, 28])
        self.x_flat = tf.contrib.layers.flatten(self.x)
        net = tf.layers.dense(self.x_flat, 512, activation=tf.nn.relu)
        net = tf.layers.dense(net, 384, activation=tf.nn.relu)
        net = tf.layers.dense(net, 256, activation=tf.nn.relu)
        
        self.z_mu = tf.layers.dense(net, self.n_latent)
        self.z_logvar = tf.layers.dense(net, self.n_latent)
        eps = tf.random_normal(shape=tf.shape(self.z_logvar),mean=0,stddev=1,dtype=tf.float32)
        self.z = self.z_mu + tf.exp(0.5*self.z_logvar)*eps
        
    def _build_decoder(self):
        net = tf.layers.dense(self.z, 256, activation=tf.nn.relu)
        net = tf.layers.dense(net, 384, activation=tf.nn.relu)
        net = tf.layers.dense(net, 512, activation=tf.nn.relu)
        self.x_hat = tf.layers.dense(net, 784, activation=tf.nn.sigmoid)
        
    def run_single_step(self,x):
        _, loss = self.sess.run([self.train_op,self.loss], feed_dict={self.x: x})
        return loss
        
    #reconstruction
    #x->x_hat
    def reconstruction(self,x):
        return self.sess.run(self.x_hat, feed_dict={self.x: x})
        
    #generation
    #z->x_hat
    def generate(self,z):
        return self.sess.run(self.x_hat,feed_dict={self.z: z})

    #transformation of features
    #x->z
    def transformer(self,x):
        return self.sess.run(self.z,feed_dict={self.x: x})

# %%
vae = VAE(5)

# %%
epoch = 10
batch_size = 32

for ep in range(epoch):
    for i in range(X_train.shape[0] // batch_size):
        loss = vae.run_single_step(X_train[i*batch_size:(i+1)*batch_size])
    print('[Epoch {}] Loss: {}'.format(ep,loss))
# Out:
# [Epoch 0] Loss: 168.06582641601562
# [Epoch 1] Loss: 148.11013793945312
# [Epoch 2] Loss: 141.0782928466797
# [Epoch 3] Loss: 137.93771362304688
# [Epoch 4] Loss: 135.33363342285156
# [Epoch 5] Loss: 133.80374145507812
# [Epoch 6] Loss: 131.7591094970703
# [Epoch 7] Loss: 129.8026885986328
# [Epoch 8] Loss: 128.39906311035156
# [Epoch 9] Loss: 127.69789123535156

# %%
h = w = 28
#reconstruction
batch = X_train[:100]
x_reconstructed = vae.reconstruction(batch)
#x_generated = model.generate(z)
n=10
I_reconstructed = np.empty((h*n,2*w*n))

for i in range(n):
    for j in range(n):
        x = np.concatenate((x_reconstructed[i*n+j,:].reshape(h,w),batch[i*n+j,:].reshape(h,w)),axis=1)
        I_reconstructed[i*h:(i+1)*h,j*2*w:(j+1)*2*w] = x
plt.figure(figsize = (10,20))
plt.imshow(I_reconstructed,cmap='gray')

# %%
# Test the trained model: generation
# Sample noise vectors from N(0, 1)
z = np.random.normal(size=[100, vae.n_latent])
x_generated = vae.generate(z)

n = 10
I_generated = np.empty((h*n, w*n))
for i in range(n):
    for j in range(n):
        I_generated[i*h:(i+1)*h, j*w:(j+1)*w] = x_generated[i*n+j, :].reshape(28, 28)

plt.figure(figsize=(8, 8))
plt.imshow(I_generated, cmap='gray')

# %%
model_2d = VAE(2)

# %%
epoch = 10
batch_size = 32

for ep in range(epoch):
    for i in range(X_train.shape[0] // batch_size):
        loss = model_2d.run_single_step(X_train[i*batch_size:(i+1)*batch_size])
    print('[Epoch {}] Loss: {}'.format(ep,loss))
# Out:
# [Epoch 0] Loss: 190.03643798828125
# [Epoch 1] Loss: 180.49234008789062
# [Epoch 2] Loss: 171.54345703125
# [Epoch 3] Loss: 162.0271453857422
# [Epoch 4] Loss: 157.7255401611328
# [Epoch 5] Loss: 154.2060089111328
# [Epoch 6] Loss: 151.97906494140625
# [Epoch 7] Loss: 150.00538635253906
# [Epoch 8] Loss: 147.07034301757812
# [Epoch 9] Loss: 147.6078643798828

# %%
# Test the trained model: transformation

z = model_2d.transformer(X_train[:1000])
plt.figure(figsize=(10, 8)) 
plt.scatter(z[:, 0], z[:, 1], c=y_train[:1000])
plt.colorbar()
plt.grid()
plt.show()

# %%
# Test the trained model: transformation
n = 20
x = np.linspace(-2, 2, n)
y = np.linspace(-2, 2, n)

I_latent = np.empty((h*n, w*n))
for i, yi in enumerate(x):
    for j, xi in enumerate(y):
        z = np.array([[xi, yi]])
        x_hat = model_2d.generate(z)
        I_latent[(n-i-1)*28:(n-i)*28, j*28:(j+1)*28] = x_hat[0].reshape(28, 28)

plt.figure(figsize=(8, 8))        
plt.imshow(I_latent, cmap="gray")

# %%
i = 2
blurred = np.copy(X_train[i])
blurred[10:15][:] = 0

# %%
plt.imshow(X_train[i], cmap='gray')

# %%
plt.imshow(blurred, cmap='gray')

# %%
x_reconstructed = vae.reconstruction(X_train[i][np.newaxis,:])
plt.imshow(x_reconstructed.reshape(28, 28), cmap='gray')

# %%
x_reconstructed = vae.reconstruction(blurred[np.newaxis,:])
plt.imshow(x_reconstructed.reshape(28, 28), cmap='gray')
