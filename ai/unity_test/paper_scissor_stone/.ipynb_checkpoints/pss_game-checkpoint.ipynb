# %%
import numpy as np
import tensorflow as tf
from numpy import newaxis
from sklearn.utils import shuffle
import matplotlib.pyplot as plt

class GameAgent:
    def __init__(self, n_actions, n_features, reward_decay=0.99,
                 learning_rate=0.01, learning_rate_decay=0.95,
                 ):
        self.state_size = n_features
        self.action_size = n_actions
        self.gamma = reward_decay   # discount rate
        self.learning_rate = learning_rate
        self.learning_rate_decay = learning_rate_decay
        self.batch_size = 64
        self.epsilon = 0.2 # used to clip
        self.epsilon_greedy = 0.02 # used in epsilon greedy strategy
        self.entfact = 1e-2 # entropy factor, to encourage exploration
        self.lam = 0.95 # gae factor
        self.memory = [] # store (s, a, r) for one agent
        self.agents = 5 # number of agents that collect memory
        self.history = {} # store the memory for different agents
        self.history['states'] = []
        self.history['actions'] = []
        self.history['oppo_states'] = []
        self.history['oppo_actions'] = []
        self.history['discounted_rs'] = []
        self._construct_nets()
        
    def _construct_nets(self):
        tf.reset_default_graph()
        self.sess = tf.Session()
        self.tfs = tf.placeholder(tf.float32, [None, self.state_size], 'state')

        # actor
        pi = self._build_anet('pi', trainable=True)
        oldpi = self._build_anet('oldpi', trainable=False)
        with tf.variable_scope('pi'):
            self.pi_probs = tf.nn.softmax(pi)
        with tf.variable_scope('oldpi'):
            self.oldpi_probs = tf.nn.softmax(oldpi)
        pi_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='pi')
        oldpi_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='oldpi')
        with tf.variable_scope('sample_action'):
            self.sample_op = tf.squeeze(tf.multinomial(pi, 1), axis=0)       # choosing action
            self.sample_op_old = tf.squeeze(tf.multinomial(oldpi, 1), axis=0)
        with tf.variable_scope('update_oldpi'):
            self.update_oldpi_op = [oldp.assign(p) for p, oldp in zip(pi_params, oldpi_params)]

        self.tfa = tf.placeholder(tf.int32, [None], 'action')
        self.tfa_oppo = tf.placeholder(tf.int32, [None], 'action_oppo')
        self.tfa_one_hot = tf.contrib.layers.one_hot_encoding(self.tfa, self.action_size)
        self.tfa_oppo_one_hot = tf.contrib.layers.one_hot_encoding(self.tfa_oppo, self.action_size)
        
        self.tfdc_r = tf.placeholder(tf.float32, [None], name="payoff")
        self.oppo_pi_probs = tf.placeholder(tf.float32, [None, self.action_size], name="oppo_pi")

        self.joint_proba = tf.reduce_sum(self.pi_probs * self.tfa_one_hot, axis=1) * tf.reduce_sum(self.oppo_pi_probs * self.tfa_oppo_one_hot, axis=1)
        self.loss = - tf.reduce_sum(self.tfdc_r * self.joint_proba)

        self.train_op = tf.train.AdadeltaOptimizer(self.learning_rate).minimize(self.loss, var_list=pi_params)

        self.saver = tf.train.Saver(max_to_keep=None)
        
        self.sess.run(tf.global_variables_initializer())
        
    def _build_anet(self, name, trainable):
        with tf.variable_scope(name):
            net = tf.layers.dense(self.tfs, 10, tf.nn.relu, trainable=trainable)
            logits = tf.layers.dense(net, self.action_size, trainable=trainable)
        return logits
    
    def choose_action(self, state, old=False): # epsilon greedy strategy
        rand = np.random.uniform(0,1,1)[0]
        if rand < self.epsilon_greedy:
            return np.random.randint(self.action_size, size=1)[0]
        if old:
            return self.sess.run(self.sample_op_old, {self.tfs: state})[0]
        return self.sess.run(self.sample_op, {self.tfs: state})[0]
    
    def remember(self, state, oppo_state, action, oppo_action, reward):
        self.memory += [[state[0], oppo_state[0], action, oppo_action, reward]]
    
    def discount_rewards(self, rewards, gamma, value_next=0.0):
        discounted_r = np.zeros_like(rewards)
        running_add = value_next
        for t in reversed(range(0, len(rewards))):
            discounted_r[t] = running_add = running_add * gamma + rewards[t]
        return discounted_r
    
    def process_memory(self):
        memory = np.vstack(self.memory)
        states = np.vstack(memory[:,0])
        oppo_states = np.vstack(memory[:,1])
        actions = memory[:,2]
        oppo_actions = memory[:,3]
        rewards = memory[:,4]
#         discounted_ep_rs = self.discount_rewards(rewards, self.gamma)[:, newaxis]
        self.history['states'] += [states]
        self.history['actions'] += [actions]
        self.history['oppo_states'] += [oppo_states]
        self.history['oppo_actions'] += [oppo_actions]
        self.history['discounted_rs'] += [rewards]
        self.memory = [] # empty the memory
    
    def replay(self, K=10):
        self.sess.run(self.update_oldpi_op)
        
        s = np.vstack(self.history['states'])
        ac = np.vstack(self.history['actions']).flatten()
        os = np.vstack(self.history['oppo_states'])
        oa = np.vstack(self.history['oppo_actions']).flatten()
        dc_r = np.vstack(self.history['discounted_rs']).flatten()
        
        for _ in range(K): # update K epochs
            s, ac, os, oa, dc_r = shuffle(s, ac, os, oa, dc_r)
            for l in range(s.shape[0]//self.batch_size):
                start = l * self.batch_size
                end = (l + 1) * self.batch_size
                oppo_pi_probs = self.sess.run(self.oldpi_probs, {self.tfs: os[start:end]})
                self.sess.run(self.train_op, {self.tfs: s[start:end], self.tfa: ac[start:end], self.oppo_pi_probs: oppo_pi_probs, self.tfa_oppo: oa[start:end], self.tfdc_r: dc_r[start:end]})
#                 self.losses += [self.sess.run(self.loss, {self.tfs: s[start:end], self.tfa: ac[start:end], self.oppo_pi_probs: oppo_pi_probs, self.tfa_oppo: oa[start:end], self.tfdc_r: dc_r[start:end]})]
            if s.shape[0] % self.batch_size != 0:
                res = s.shape[0] % self.batch_size
                oppo_pi_probs = self.sess.run(self.oldpi_probs, {self.tfs: os[-res:]})
                self.sess.run(self.train_op, {self.tfs: s[-res:], self.tfa: ac[-res:], self.oppo_pi_probs: oppo_pi_probs, self.tfa_oppo: oa[-res:], self.tfdc_r: dc_r[-res:]})
#                 self.losses += [self.sess.run(self.loss, {self.tfs: s[-res:], self.tfa: ac[-res:], self.oppo_pi_probs: oppo_pi_probs, self.tfa_oppo: oa[-res:], self.tfdc_r: dc_r[-res:]})]
        
        for key in self.history:
            self.history[key] = [] # empty the history

# %%
agent = GameAgent(n_actions=3, n_features=2, learning_rate=1e-4)

# %% [markdown]
# # Paper = 0, Scissors = 1, Stone = 2
# # player1's state = [0,1], player2's state = [1,0]

# %% [markdown]
# ### If the second player always plays paper

# %%
oppo = 0
state = [[0,1]]
p = agent.sess.run(agent.pi_probs, {agent.tfs: state})[0]
proba0 = [p[0]]
proba1 = [p[1]]
proba2 = [p[2]]
for ep in range(2000):
    action = agent.choose_action(state)
    if action == 0:
        reward = 0
    elif action == 1:
        reward = 1
    else:
        reward = -1
    agent.remember(state, [action], reward)
    agent.process_memory()
    if (ep+1) % 5 == 0:
        agent.replay()
    if (ep+1) % 10 == 0:
        p = agent.sess.run(agent.pi_probs, {agent.tfs: state})[0]
        proba0 += [p[0]]
        proba1 += [p[1]]
        proba2 += [p[2]]

# %%
plt.plot(proba0, label="P(paper)")
plt.plot(proba1, label="P(scissor)")
plt.plot(proba2, label="P(stone)")
plt.xlabel('*10 games')
plt.ylabel('probability')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### The probability of choosing scissor increases

# %% [markdown]
# ____
# ### Now, if the opponent changes the strategy, plays scissor with proba 1/2 and stone with proba 1/2

# %%
state = [[0,1]]
p = agent.sess.run(agent.pi_probs, {agent.tfs: state})[0]
proba0 = [p[0]]
proba1 = [p[1]]
proba2 = [p[2]]
for ep in range(2000):
    ran = np.random.uniform(0,1,1)
    if ran[0] > 0.5:
        oppo = 1
    else:
        oppo = 2
    action = agent.choose_action(state)
    if oppo==1:
        if action==0:
            reward = -1
        elif action==1:
            reward = 0
        else:
            reward = 1
    else:
        if action==0:
            reward = 1
        elif action==1:
            reward = -1
        else:
            reward = 0
    agent.remember(state, [action], reward)
    agent.process_memory()
    if (ep+1) % 5 == 0:
        agent.replay()
    if (ep+1) % 10 == 0:
        p = agent.sess.run(agent.pi_probs, {agent.tfs: state})[0]
        proba0 += [p[0]]
        proba1 += [p[1]]
        proba2 += [p[2]]

# %%
plt.plot(proba0, label="P(paper)")
plt.plot(proba1, label="P(scissor)")
plt.plot(proba2, label="P(stone)")
plt.xlabel('*10 games')
plt.ylabel('probability')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Playing only stones is the best strategy

# %% [markdown]
# ____
# ## Now, play against itself

# %%
agent = GameAgent(n_actions=3, n_features=2, learning_rate=1e-1)

# %%
player1_state = [[0,1]]
player2_state = [[1,0]]
p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
player1_proba_paper = [p[0]]
player1_proba_scissors = [p[1]]
player1_proba_stone = [p[2]]
player2_proba_paper = [p_[0]]
player2_proba_scissors = [p_[1]]
player2_proba_stone = [p_[2]]
losses = []
eps = 500

for ep in range(eps):
    agent.remember(player1_state, player2_state, 0, 0, 0)
    agent.remember(player1_state, player2_state, 0, 1, -1)
    agent.remember(player1_state, player2_state, 0, 2, 1)
    agent.remember(player1_state, player2_state, 1, 0, 1)
    agent.remember(player1_state, player2_state, 1, 1, 0)
    agent.remember(player1_state, player2_state, 1, 2, -1)
    agent.remember(player1_state, player2_state, 2, 0, -1)
    agent.remember(player1_state, player2_state, 2, 1, 1)
    agent.remember(player1_state, player2_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(10)
    
    agent.remember(player2_state, player1_state, 0, 0, 0)
    agent.remember(player2_state, player1_state, 0, 1, -1)
    agent.remember(player2_state, player1_state, 0, 2, 1)
    agent.remember(player2_state, player1_state, 1, 0, 1)
    agent.remember(player2_state, player1_state, 1, 1, 0)
    agent.remember(player2_state, player1_state, 1, 2, -1)
    agent.remember(player2_state, player1_state, 2, 0, -1)
    agent.remember(player2_state, player1_state, 2, 1, 1)
    agent.remember(player2_state, player1_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(5)
    
    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    oppo_pi_probs = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})
    losses += [-agent.sess.run(agent.loss, {agent.tfs: player1_state, agent.oppo_pi_probs: oppo_pi_probs, 
                        agent.tfa: [0,0,0,1,1,1,2,2,2], agent.tfa_oppo:[0,1,2,0,1,2,0,1,2], 
                        agent.tfdc_r: [0,-1,1,1,0,-1,-1,1,0]})]

    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    player1_proba_paper += [p[0]]
    player1_proba_scissors += [p[1]]
    player1_proba_stone += [p[2]]
    player2_proba_paper += [p_[0]]
    player2_proba_scissors += [p_[1]]
    player2_proba_stone += [p_[2]]

# %%
print('optimal strategy :')
print('P1(paper) =', np.mean(player1_proba_paper), 'P1(scissors) =', np.mean(player1_proba_scissors), 'P1(stone) =', np.mean(player1_proba_stone))
print('P2(paper) =', np.mean(player2_proba_paper), 'P2(scissors) =', np.mean(player2_proba_scissors), 'P2(stone) =', np.mean(player2_proba_stone))
# Out:
# optimal strategy :
# P1(paper) = 0.311847 P1(scissors) = 0.329581 P1(stone) = 0.358572
# P2(paper) = 0.325248 P2(scissors) = 0.353499 P2(stone) = 0.321253

# %%
plt.subplots(figsize=(20,5))

plt.subplot(121)
plt.plot(player1_proba_paper, label="P1(paper)")
plt.plot(player1_proba_scissors, label="P1(scissors)")
plt.plot(player1_proba_stone, label="P1(stone)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.subplot(122)
plt.plot(player2_proba_paper, label="P2(paper)")
plt.plot(player2_proba_scissors, label="P2(scissors)")
plt.plot(player2_proba_stone, label="P2(stone)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.show()

# %%
plt.title("Player 1's expected payoff in NE")
plt.plot(losses)
plt.show()
print('expected reward =',np.mean(losses[-100:]))
# Out:
# expected reward = -2.60107e-06

# %% [markdown]
# # The strategies converge to the mixed strategy NE!!

# %%
agent.saver.save(agent.sess, "model/pss_self_play1500.ckpt");
# Out:
# INFO:tensorflow:model/pss_self_play1500.ckpt is not in all_model_checkpoint_paths. Manually adding it.

# %% [markdown]
# ---
# # Tweaked paper-scissors-stone : (2,-2) on the upper right corner

# %% [markdown]
#   | paper    | scissors    | stone
#  ------|------|------|------|
#  paper     |   (0,0)  | (-1,1)|(2,-2)
#  scissors     |   (1,-1)  | (0,0)|(-1,1)
#  stone     |   (-1,1)  | (1,-1)| (0,0)

# %%
agent = GameAgent(n_actions=3, n_features=2, learning_rate=1e-1)

# %%
player1_state = [[0,1]]
player2_state = [[1,0]]
p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
player1_proba_paper = [p[0]]
player1_proba_scissors = [p[1]]
player1_proba_stone = [p[2]]
player2_proba_paper = [p_[0]]
player2_proba_scissors = [p_[1]]
player2_proba_stone = [p_[2]]
losses = []
eps = 500

for ep in range(eps):
    agent.remember(player1_state, player2_state, 0, 0, 0)
    agent.remember(player1_state, player2_state, 0, 1, -1)
    agent.remember(player1_state, player2_state, 0, 2, 2)
    agent.remember(player1_state, player2_state, 1, 0, 1)
    agent.remember(player1_state, player2_state, 1, 1, 0)
    agent.remember(player1_state, player2_state, 1, 2, -1)
    agent.remember(player1_state, player2_state, 2, 0, -1)
    agent.remember(player1_state, player2_state, 2, 1, 1)
    agent.remember(player1_state, player2_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(10)
    
    agent.remember(player2_state, player1_state, 0, 0, 0)
    agent.remember(player2_state, player1_state, 0, 1, -1)
    agent.remember(player2_state, player1_state, 0, 2, 1)
    agent.remember(player2_state, player1_state, 1, 0, 1)
    agent.remember(player2_state, player1_state, 1, 1, 0)
    agent.remember(player2_state, player1_state, 1, 2, -1)
    agent.remember(player2_state, player1_state, 2, 0, -2)
    agent.remember(player2_state, player1_state, 2, 1, 1)
    agent.remember(player2_state, player1_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(5)
    
    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    oppo_pi_probs = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})
    losses += [-agent.sess.run(agent.loss, {agent.tfs: player1_state, agent.oppo_pi_probs: oppo_pi_probs, 
                        agent.tfa: [0,0,0,1,1,1,2,2,2], agent.tfa_oppo:[0,1,2,0,1,2,0,1,2], 
                        agent.tfdc_r: [0,-1,2,1,0,-1,-1,1,0]})]

    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    player1_proba_paper += [p[0]]
    player1_proba_scissors += [p[1]]
    player1_proba_stone += [p[2]]
    player2_proba_paper += [p_[0]]
    player2_proba_scissors += [p_[1]]
    player2_proba_stone += [p_[2]]

# %%
plt.subplots(figsize=(20,5))

plt.subplot(121)
plt.plot(player1_proba_paper, label="P1(paper)")
plt.plot(player1_proba_scissors, label="P1(scissors)")
plt.plot(player1_proba_stone, label="P1(stone)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.subplot(122)
plt.plot(player2_proba_paper, label="P2(paper)")
plt.plot(player2_proba_scissors, label="P2(scissors)")
plt.plot(player2_proba_stone, label="P2(stone)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.show()
l = 100
print('optimal strategy :')
print('P1(paper) =', np.mean(player1_proba_paper[-l:]), 'P1(scissors) =', np.mean(player1_proba_scissors[-l:]), 'P1(stone) =', np.mean(player1_proba_stone[-l:]))
print('P2(paper) =', np.mean(player2_proba_paper[-l:]), 'P2(scissors) =', np.mean(player2_proba_scissors[-l:]), 'P2(stone) =', np.mean(player2_proba_stone[-l:]))
# Out:
# optimal strategy :
# P1(paper) = 0.249585 P1(scissors) = 0.416667 P1(stone) = 0.333749
# P2(paper) = 0.333521 P2(scissors) = 0.416524 P2(stone) = 0.249955

# %%
plt.title("Player 1's expected payoff in NE")
plt.plot(losses)
plt.show()
print('expected reward =',np.mean(losses[-100:]))
# Out:
# expected reward = 0.0833303

# %%
agent.saver.save(agent.sess, "model/pss_tweaked_self_play1500.ckpt");
# Out:
# INFO:tensorflow:model/pss_tweaked_self_play1500.ckpt is not in all_model_checkpoint_paths. Manually adding it.

# %% [markdown]
# # The strategies converge to the mixed strategy NE!!

# %% [markdown]
# # A general method to calculate the mixed strategy NE given a payoff matrix :
# ## 1. Eliminate strictly dominated strategies

# %% [markdown]
# <table>
# <caption align="bottom"><i>A zero-sum game</i></caption>
# <tbody><tr>
# <th style="background:linear-gradient(to top right,#eaecf0 49.5%,#aaa 49.5%,#aaa 50.5%,#eaecf0 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">Blue</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">Red</span></div>
# </th>
# <th><span style="color:blue"><i>A</i></span></th>
# <th><span style="color:blue"><i>B</i></span></th>
# <th><span style="color:blue"><i>C</i></span></th>
# </tr>
# <tr>
# <th><span style="color:red"><i>1</i></span></th>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">-30</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">30</span></div>
# </td>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">10</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">-10</span></div>
# </td>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">-20</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">20</span></div>
# </td>
# </tr>
# <tr>
# <th><span style="color:red"><i>2</i></span></th>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">10</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">-10</span></div>
# </td>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">-20</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">20</span></div>
# </td>
# <td style="background:linear-gradient(to top right,white 49.5%,#aaa 49.5%,#aaa 50.5%,white 50.5%);line-height:1;">
# <div style="margin-left:2em;text-align:right;"><span style="color:blue">20</span></div>
# <div style="margin-right:2em;text-align:left;"><span style="color:red">-20</span></div>
# </td>
# </tr>
# </tbody></table>

# %% [markdown]
# In this example from wikipedia, for player Blue, the choice A is strictly dominated by choice C, since no matter what Red player chooses, he can always get better payoffs by choosing C instead of A (-20>-30 when Red chooses 1, and 20>10 when Red chooses 2)

# %% [markdown]
# ## 2. Calculated the mixed strategy by setting probability variables
# Suppose that there's no strictly dominated strategies now (if there is any, set the probability to be zero), we can now assign probability variables to choices and solve a equation system.
#
# Take the tweaked paper-scissors-stone for example:
#
#   | q1   | q2   | q3
#  ------|------|------|------|
#  p1    |   (0,0)  | (-1,1)|(2,-2)
# p2    |   (1,-1)  | (0,0)|(-1,1)
# p3 |   (-1,1)  | (1,-1)| (0,0)
#
# Player 1 is the row player and Player 2 is the column player.

# %% [markdown]
# Player 2's strategy needs to be such that Player 1 is indifferent between his pure strategies, which means he gets the same expected payoffs no matter he chooses purely choice 1 or 2 or 3.
#
# Mathematically, $$\mathbb{E}(row_1) = \mathbb{E}(row_2) = \mathbb{E}(row_3)$$
#
# Therefore, $$ q_2-2q_3 = -q_1 + q_3 = q_1 - q_2$$
#
# With the sum of the probabilities $$ q_1+q_2+q_3 = 1$$ we can solve this system.
#
# Finally, $$q_1 = \dfrac{1}{3}, q_2 = \dfrac{5}{12}, q_3 = \dfrac{1}{4}$$
#
# which is the mixed strategy in NE.
#
# Analogously, by solving $$\mathbb{E}(col_1) = \mathbb{E}(col_2) = \mathbb{E}(col_3)$$ we can get the mixed strategy for Player 1 :
#
# $$p_1 = \dfrac{1}{4}, p_2 = \dfrac{5}{12}, p_3 = \dfrac{1}{3}$$
#
# which matches the result we get in the simulation previously.

# %% [markdown]
# ---
# # Other 3 choices games

# %% [markdown]
# # Hide and seek around a pillar
# Two players, a ghost and a human, standing on the opposite side of a pillar (a cylider) so that they cannot see each other.
# At each turn, both players decide to go left or to go right by turning around the pillar by 90 degrees, or to not move at all.
# The game finishes when they can see each other (i.e. the angle between them is < 180 degrees), and the ghost wins in this case (the human never wins, he can only try to escape from the ghost's sight all the time).
#
# The game can be described using the following payoff matrix :

# %% [markdown]
#   | left    | no move    | right
#  ------|------|------|------|
# left     |   (0,0)  | (1,-1)|(1,-1)
# no move     |   (1,-1)  | (0,0)|(1,-1)
# right   |   (1,-1)  | (1,-1)| (0,0)

# %% [markdown]
# The row player is the ghost, and the column player is the human.

# %%
agent = GameAgent(n_actions=3, n_features=2, learning_rate=1e-1)

# %%
player1_state = [[0,1]]
player2_state = [[1,0]]
p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
player1_proba_left = [p[0]]
player1_proba_no_move = [p[1]]
player1_proba_right = [p[2]]
player2_proba_left = [p_[0]]
player2_proba_no_move = [p_[1]]
player2_proba_right = [p_[2]]
losses = []
eps = 500

for ep in range(eps):
    agent.remember(player1_state, player2_state, 0, 0, 0)
    agent.remember(player1_state, player2_state, 0, 1, 1)
    agent.remember(player1_state, player2_state, 0, 2, 1)
    agent.remember(player1_state, player2_state, 1, 0, 1)
    agent.remember(player1_state, player2_state, 1, 1, 0)
    agent.remember(player1_state, player2_state, 1, 2, 1)
    agent.remember(player1_state, player2_state, 2, 0, 1)
    agent.remember(player1_state, player2_state, 2, 1, 1)
    agent.remember(player1_state, player2_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(10)
    
    agent.remember(player2_state, player1_state, 0, 0, 0)
    agent.remember(player2_state, player1_state, 0, 1, -1)
    agent.remember(player2_state, player1_state, 0, 2, -1)
    agent.remember(player2_state, player1_state, 1, 0, -1)
    agent.remember(player2_state, player1_state, 1, 1, 0)
    agent.remember(player2_state, player1_state, 1, 2, -1)
    agent.remember(player2_state, player1_state, 2, 0, -1)
    agent.remember(player2_state, player1_state, 2, 1, -1)
    agent.remember(player2_state, player1_state, 2, 2, 0)
    agent.process_memory()
    agent.replay(5)
    
    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    oppo_pi_probs = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})
    losses += [-agent.sess.run(agent.loss, {agent.tfs: player1_state, agent.oppo_pi_probs: oppo_pi_probs, 
                        agent.tfa: [0,0,0,1,1,1,2,2,2], agent.tfa_oppo:[0,1,2,0,1,2,0,1,2], 
                        agent.tfdc_r: [0,1,1,1,0,1,1,1,0]})]

    p = agent.sess.run(agent.pi_probs, {agent.tfs: player1_state})[0]
    p_ = agent.sess.run(agent.pi_probs, {agent.tfs: player2_state})[0]
    player1_proba_left += [p[0]]
    player1_proba_no_move += [p[1]]
    player1_proba_right += [p[2]]
    player2_proba_left += [p_[0]]
    player2_proba_no_move += [p_[1]]
    player2_proba_right += [p_[2]]

# %%
plt.subplots(figsize=(20,5))

plt.subplot(121)
plt.plot(player1_proba_left, label="P1(left)")
plt.plot(player1_proba_no_move, label="P1(no_move)")
plt.plot(player1_proba_right, label="P1(right)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.subplot(122)
plt.plot(player2_proba_left, label="P2(left)")
plt.plot(player2_proba_no_move, label="P2(no_move)")
plt.plot(player2_proba_right, label="P2(right)")
plt.xlabel('number of games')
plt.ylabel('probability')
plt.legend(loc='best')

plt.show()
print('optimal strategy :')
print('P1(left) =', np.mean(player1_proba_left), 'P1(no_move) =', np.mean(player1_proba_no_move), 'P1(right) =', np.mean(player1_proba_right))
print('P2(left) =', np.mean(player2_proba_left), 'P2(no_move) =', np.mean(player2_proba_no_move), 'P2(right) =', np.mean(player2_proba_right))
# Out:
# optimal strategy :
# P1(left) = 0.334843 P1(no_move) = 0.342597 P1(right) = 0.32256
# P2(left) = 0.339817 P2(no_move) = 0.335511 P2(right) = 0.324671

# %%
plt.title("Player 1's expected payoff in NE")
plt.plot(losses)
plt.show()
print('expected reward =',np.mean(losses[-100:]))
# Out:
# expected reward = 0.666667

# %% [markdown]
# # The strategies converge to the NE, where both players choose each option with equal proba (1/3), and the ghost wins with proba 2/3 = 0.666667

# %% [markdown]
# ____
# # Some maths about the convergence of our method

# %% [markdown]
# For a normal paper-scissors-stone game, if we write the expected reward for both players using the following table:
#
# | q1    | q2    | q3
#  ------|------|------|------|
#  p1     |   (0,0)  | (1,-1)|(-1,1)
#  p2     |   (-1,1)  | (0,0)|(1,-1)
#  p3     |   (1,-1)  | (-1,1)| (0,0)

# %% [markdown]
# Then $\mathbb{E}(R_1) = p_1q_2-p_1q_3-p_2q_1+p_2q_3+p_3q_1-p_3q_2.$
#
# If we play as the first player, then our objective is to maximize this expectation given the opponent's strategy, i.e. maximize $\mathbb{E}_{q=(q_1,q_2,q_3)\ \text{fixed}}(R_1).$
#
# Therefore, we need to follow the gradient of $p$ (here it's just the derivative) using gradient $\textbf{ascent}$ since we want to maximize the reward. We assume that $p$ and $q$ are both functions over $t$, the time (or the number of steps).
#
# After calculation, we get
# \begin{align}
# p_1' &= q_2 - q_3 \\
# p_2' &= -q_1+q_3 \\
# p_3' &= q_1-q_2
# \end{align}
# And analogously,
#
# \begin{align}
# q_1' &= p_2 - p_3 \\
# q_2' &= -p_1+p_3 \\
# q_3' &= p_1-p_2
# \end{align}
# by differentiating $\mathbb{E}_{p=(p_1,p_2,p_3)\ \text{fixed}}(R_2)$ with respect to $p$.

# %% [markdown]
# By combining some of these equations, we can get a second order differential equation in $p_1$ as follows :
#
# $$p_1''+3p_1 = 1$$
#
# which admits a general solution, $p_1 = A\cos(\sqrt{3}t+\phi) + \dfrac{1}{3}$, where $A$ and $\phi$ are constants.
#
# As we can see, the solution will oscillate around the optimal value, $\dfrac{1}{3}$, but will $\textbf{never}$ converge to it.

# %% [markdown]
# To get a convergent $p$ (and also $q$), we need to use $\textbf{asynchronous update}$.
#
# In my implementation, I updated $p$ first then $q$. This helps us have both $p$ and $q$ converge.
#
# This slight modification changes the equation system for $q$ to become the following:
#
# \begin{align}
# q_1' &= (p_2+\eta p_2') - (p_3 + \eta p_3') \\
# q_2' &= -(p_1+\eta p_1')+(p_3 + \eta p_3') \\
# q_3' &= (p_1+\eta p_1')-(p_2+\eta p_2')
# \end{align}
#
# where $\eta$ is a small value, equal to the learning rate (usually between $10^{-2}$ and $10^{-5}$, depending on the problem).

# %% [markdown]
# By combining these new equations with the initial equation system of $p$, we can deduce a new second order equation for $p_1$ as follows:
#
# $$p_1''+3\eta p_1' +3p_1 = 1$$
#
# whose solution is now convergent.
#
# After calculation, $p_1 = Ae^{\alpha t}\cos(\sqrt{3}t+\phi) + \dfrac{1}{3}$, where $A$ and $\phi$ are constants, and $\alpha = -1.5\eta$.
#
# The negative sign in the exponential function means that the first term will tend to zero at infinity.
#
# Therefore, $\displaystyle \lim_{t\rightarrow \infty}(p_1) = \frac{1}{3}$. Similarly, we can show that all other functions also tend to $\dfrac{1}{3}$ at infinity.
