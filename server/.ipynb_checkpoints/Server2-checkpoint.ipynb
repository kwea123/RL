# %%
import socket
from PIL import Image
import numpy as np
import io
import sys
import cv2

# %%
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
host = '0.0.0.0'
port = 5555
sock.bind((host, port))
sock.listen()

# %%
(client_sock, client_addr) = sock.accept()
print("Client Info: ", client_sock, client_addr)
# Out:
# Client Info:  <socket.socket fd=1044, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 5555), raddr=('127.0.0.1', 50169)> ('127.0.0.1', 50169)

# %%
msg = client_sock.recv(1024000)
print(sys.getsizeof(msg))
# Out:
# 469153

# %%
img = Image.open(io.BytesIO(msg))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3840x2160 at 0x22F2BD81550>

# %%
sock.close()
